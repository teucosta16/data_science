# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# LEITURA DE DADOS

# %%
#Masculino

dataM = pd.read_csv('morte_naso_masc.csv', sep=';', encoding='ISO-8859-1')

#Feminino

dataF = pd.read_csv('mortes_naso_femini.csv', sep=';', encoding='ISO-8859-1')
#dataF.head()
dataM.head()
# Out:
#     ANO  OBITO_TOTAL  OBITO_CANCER PERCENTUAL
# 0  1979       409085            65       0,02
# 1  1980       431039            54       0,01
# 2  1981       433002            60       0,01
# 3  1982       431429            59       0,01
# 4  1983       450396            48       0,01

# %% [markdown]
# Tratamento dos dados

# %%
plt.plot(dataF['ANO'], dataF['OBITO_TOTAL'])
plt.plot(dataM['ANO'], dataM['OBITO_TOTAL'], color='#FCD158')


plt.yscale('log')
